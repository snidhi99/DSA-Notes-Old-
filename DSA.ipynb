# %% [markdown]
# C/C++

# %%
/* COMMENT */
'''these are header files pulled from cd /usr/include'''
#include<stdio.h>
#include<stdlib.h>
#include<time.h>


'''These are C preprocessor directives'''
'''COUNT constant'''
#define COUNT 10

'''string literal'''
#define GREETING "Howdy!"

'''substitution macros'''
#define charout(a) putc(a,stdout)

int a,b; #outside func, used when extern keyword called inside func

void sum(void)
{
    auto int a,b; #private and local to function : auto. Value released after function quits
    a=1;
    b=2;
    print("%d + %d = %d \n",a,b,a+b)

}

void sub(void)
{
    static a = 5; #static : retains value after exiting func.
    extern int a,b;  #extern: searches for a,b declared outside func.
    a=1;
    b=2;
    print("%d + %d = %d \n",a,b,a-b)

}

#TYPE CASTING
void div
{
    int a = 10, b = 3;
    printf("%d / %d = %f",a,b,(float)a/b) #enclosing (float) is typecasting
}

#increment a++ #this is a = a+1
#++a is basically a+1 = a
#decrement a--

#ORDER OF PRECEDENCE: left to right,
first brackets ()
second unary ! ~ = + * & ++ --
third math * / - +
fourth comparison  < > <= >= == !=
fifth binary & ^ |
last = , ?:

#LOGICAL OP
while (a<=10)
{
    if (a>=2 && a <= 9)
    {
        print("True")
    }
}

int main()
{
    float a; #char, int, double available
    puts(GREETING);
    const int count = 4; #const is keyword, cant be changed

    typedef float radius; #typedef: define radius as a datatype
    radius a; #similar to calling float a
    a=45.5;

    for (a=0;a<COUNT;a++)
    {
        puts("Hi");
        putchar('H')
        printf("Enter");
        scanf("%d",&a) # %c for character, %f for float, %d for double, %% for single percent
        printf("The value entered is %0.2f \n",a) #float formatting (2 decimals)
    }
}






'''
Run:
vim file.c
gcc file.c
./a.out


Py: Pass keyword
C: break keyword'''

# %% [markdown]
# Arrays (Like lists)
# - Collection of similar data elements
# - int A[5]          =  {1,2,3,4,5}
#   (Array declaration = Array initialization)
#
#
#   Main memory is split as:
#   HEAP         | |
#   STACK        | |
#   MAIN         | |
#   CODE SECTION | |

# %%
#C, C++ CODE

#include<stdio.h>
#include<iostream>

using namespace std;

int main{
    int A[5];
    A[0] = 11;
    A[1] = 12;
    A[2] = 13;

    cout<<sizeof(A)<<endl; #O/P: 5*4(int) = 20
    cout<<A[1]<<endl;
    printf("%d\n",A[2])
    return 0;
}


a[10]={}
#C
for(int i=0;i<10;i++){
    printf("",A[i])
}

#C++
for(int x:A){
    cout<<x<<endl;
}

# %%
#Variable sized arrays cannot be initialized

using namespace std;

int main{
    int n;
    cout<<"Enter size";
    cin>>n;
    #THE BELOW LINE IS NOT POSSIBLE
    #int A[n]={1,2,3,4} #can't initialize it this way.
    #instead do this way (below)
    A[0] = 11;
    A[1] = 12;
    A[2] = 13;

    cout<<sizeof(A)<<endl; #O/P: 5*4(int) = 20
    cout<<A[1]<<endl;
    printf("%d\n",A[2])
    return 0;
}
